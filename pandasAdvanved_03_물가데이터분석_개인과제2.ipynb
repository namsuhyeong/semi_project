# %% [markdown]
# 서울시 물가정보 분석

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 그래프를 노트북 안에 그리기 위한 설정

# %matplotlib inline

# matplotlib 한글 폰트 오류 문제 해결

from matplotlib import font_manager, rc
import matplotlib as mpl
font_path = '../data/malgun.ttf' # data 폴더에 font 파일 넣어놓은 뒤 그 파일을 경로로 지정한것. 꼭 데이터 폴더에 파일 넣어 놔야 제대로 작동.
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
# 마이너스 깨짐 현상 해결
mpl.rcParams['axes.unicode_minus'] = False

# %%
# In-class Practice 

# 미션 : 달걀 가격 분석해 보세요. 
# 조건 : 포함되어야 할 문자 : 달걀, 30개(실판매규격)

# %%
# 데이터 수집

path = '../data/생필품 농수축산물 가격 정보(2021년1월_6월).csv'

df = pd.read_csv(path, encoding='cp949')

# %%
df
# Out:
#           일련번호  시장/마트 번호  시장/마트 이름  품목 번호       품목 이름      실판매규격  가격(원)  \
# 0      1673336         2    신세계백화점    133      무(세척무)         1개   2980
# 1      1667985       228    방배종합시장     23          상추     1봉150g   1500
# 2      1666935         1      통인시장    266  고등어(생물,국산)        1마리   4000
# 3      1671116        25  방학동도깨비시장    268  고등어(냉동,국산)       350g   2500
# 4      1667066         6   이마트 용산점    171     달걀(10개)        15구   5980
# ...        ...       ...       ...    ...         ...        ...    ...
# 42694  1636118       226  롯데마트 구로점    171     달걀(10개)  10개(600g)   2990
# 42695  1636108       226  롯데마트 구로점     27           배  1개 (600g)   1590
# 42696  1636114       226  롯데마트 구로점    312         애호박  1개 (300g)   2790
# 42697  1636113       226  롯데마트 구로점     22          오이  1개 (200g)   1190
# 42698  1636121       226  롯데마트 구로점    302          명태  1마리(600g)   1670
#
#           년도-월          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# ...

# %%
df.columns
# Out:
# Index(['일련번호', '시장/마트 번호', '시장/마트 이름', '품목 번호', '품목 이름', '실판매규격', '가격(원)',
#        '년도-월', '비고', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드',
#        '자치구 이름', '점검일자'],
#       dtype='object')

# %%
condition =(df['품목 이름'].str.contains('달걀'))

# %%
df[condition]['실판매규격'].unique()
# Out:
# array(['15구', '1.8kg', '10개', '30개', '30개(1800g)', '10개(600g)', '특란670g',
#        '1800g', '10구', '30구', '10개(특란)', '30개(특란)', '30개(1.5kg)',
#        '10개(특란 600g)', '특란1750g', '특란17500g', '10개(520g)', '10개(500g)',
#        '25개', '30갸', '10개600g', '특란1.8kg', '10개520g', '특란690g', '특란1830g',
#        '10개 ', '500g', '30개1,560g', '30개(특란 1800g)', '25개(1300g)',
#        '30개(1700g)', '15개(900g)', '31개(특란)', '특란580g', '15개(특란) 900g',
#        '10개(대란)', '30개 ', '30개(대란)', '15rn', '30개(2.04kg)', '10개(680g)',
#        '30개(1.8kg)', '15개', '30개(개란)', '30개(1560g)', '30개(1.56kg)',
#        '30개(1500g)', '2040g', '650g', '10개(550g)', '30개(2,040g)', '550g',
#        '10개(650g)', '2000g', '30개(2000g)', '10개(580g)', '30개(2,000g)',
#        '580g', '30개(1,560g)', '1560g', '520g', '1880g', '600g',
#        '30개1,800g', '10개(620g)', '특란', '30개(대란 1,560g)', '30개(1.8cm)',
#        '1마리(1.5kg)', '30규', '10두', '10개 (600g)', '30개(1860g)', '특란600g',
# ...

# %%
condition_temp1 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='1.5kg')]
condition_temp2 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='1.7kg')]
condition_temp3 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='1마리(1.5kg)')]
condition_temp4 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='1마리1kg')]
condition_temp5 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='30개(1.5kg)')]
condition_temp6 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='30개(1500g)')]
condition_temp7 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='2000g')]
condition_temp8 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='30개(2000g)')]
condition_temp9 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='30개(2,000g)')]
condition_temp10 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='1마리(1.5kg)')]
condition_temp11 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='1.5kg')]
condition_temp12 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='30개 2.01kg')]
condition_temp13 = df[(df['품목 이름'].str.contains('달걀'))&(df['실판매규격'] =='30개(2.01kg)')]

# %%
condition_temp1
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름  실판매규격  가격(원)     년도-월  \
# 15585  1655512        28   홈플러스 방학점    320  달걀(30개)  1.5kg   7950  2021-04
# 16344  1655529        25   방학동도깨비시장    320  달걀(30개)  1.5kg   8000  2021-04
# 16445  1653112        25   방학동도깨비시장    320  달걀(30개)  1.5kg   8000  2021-04
# 17177  1653146        26       신창시장    320  달걀(30개)  1.5kg   8000  2021-04
# 17194  1655546        26       신창시장    320  달걀(30개)  1.5kg   8000  2021-04
# 17782  1655478       221       숭인시장    320  달걀(30개)  1.5kg   8000  2021-04
# 18198  1655461        66     수유재래시장    320  달걀(30개)  1.5kg   8000  2021-04
# 18497  1653163        28   홈플러스 방학점    320  달걀(30개)  1.5kg   7950  2021-04
# 18773  1655444        68  롯데백화점 미아점    320  달걀(30개)  1.5kg  10800  2021-04
# 19471  1652441       221       숭인시장    320  달걀(30개)  1.5kg   8000  2021-04
# 20136  1655427       206  하나로클럽 미아점    320  달걀(30개)  1.5kg   7480  2021-04
# ...

# %%
condition_temp1['품목 이름'].unique()
# Out:
# array(['달걀(30개)'], dtype=object)

# %%
condition_temp1['비고'].unique()
# Out:
# array(['국내산  특란', '국내산 특란', '국내산 자연산 특란', '국내산 자연란특란'], dtype=object)

# %%
condition_temp2
# 확인필요.
# Out:
#           일련번호  시장/마트 번호 시장/마트 이름  품목 번호    품목 이름  실판매규격  가격(원)     년도-월   비고  \
# 37605  1633445        66   수유재래시장    320  달걀(30개)  1.7kg   6500  2021-01  국내산
#
#        시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 37605                  1              전통시장  305000    강북구  2021-01-28

# %%
condition_temp3['품목 이름'].unique()
# Out:
# array(['달걀(왕란)'], dtype=object)

# %%
condition_temp3['비고'].unique()
# Out:
# array(['국내산'], dtype=object)

# %%
condition_temp3
# 확인필요.
# Out:
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호   품목 이름       실판매규격  가격(원)     년도-월  \
# 5280  1668177       205  둔촌역전통시장    181  달걀(왕란)  1마리(1.5kg)   8000  2021-06
#
#        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 5280  국내산                  1              전통시장  740000    강동구  2021-06-24

# %%
condition_temp4['품목 이름'].unique()
# Out:
# array(['달걀(30개)'], dtype=object)

# %%
condition_temp4['비고'].unique()
# Out:
# array(['신선특란'], dtype=object)

# %%
condition_temp4
# 확인필요.
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호    품목 이름   실판매규격  가격(원)     년도-월  \
# 15991  1653010       123  홈플러스 월드컵점    320  달걀(30개)  1마리1kg   6780  2021-04
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 15991  신선특란                  2              대형마트  440000    마포구  2021-04-29

# %%
print(condition_temp5['품목 이름'].unique())
print()
print(condition_temp5['비고'].unique())
print()
print(condition_temp5)

# 1.5kg이면 중란인데 특란으로 되어있음 확인필요.
# Out:
# ['달걀(30개)' '달걀']
#
# ['국내산,특란' '국내산,영양특란' '국내산,안심,특란' '국내산,영양,특란' '국내산,특란,세일' '국내산,안심특란'
#  '국내산(특란)' '국내산,영양(특란)' '국내산,신선,특란']
#
#           일련번호  시장/마트 번호     시장/마트 이름  품목 번호    품목 이름       실판매규격  가격(원)  \
# 302    1674144       108        남구로시장    320  달걀(30개)  30개(1.5kg)   8000
# 414    1669381       108        남구로시장    320  달걀(30개)  30개(1.5kg)  75000
# 626    1674161       109       고척근린시장    320  달걀(30개)  30개(1.5kg)   8500
# 686    1669364       109       고척근린시장    320  달걀(30개)  30개(1.5kg)   8000
# 1958   1667526       120         망원시장    320  달걀(30개)  30개(1.5kg)   9300
# ...        ...       ...          ...    ...      ...         ...    ...
# 42266  1637303       121     마포농수산물시장    320  달걀(30개)  30개(1.5kg)   7500
# 42308  1633802       121     마포농수산물시장    320  달걀(30개)  30개(1.5kg)   6600
# 42444  1633751       224  농협하나로마트 신촌점    320  달걀(30개)  30개(1.5kg)   7770
# 42606  1636085       109       고척근린시장    320  달걀(30개)  30개(1.5kg)   6000
# ...
